# %%
import openpyxl
import pandas as pd

# %%
from src.datos.InformacionModelo import InformacionModelo

# %%
info = InformacionModelo(
    path_excel="../../data/raw/BD Matrícula Sector Estatal 2021_2024.xlsx"
)

# %%
info.ejecutar_todo()
# Out:
# Cargando Excel del CONARE...
# Carga completada ✔️
# Filtrando columnas útiles...
# Columnas preparadas ✔️
# Generando llave única de estudiante...
# Llaves generadas ✔️
# Creando variable DESERTA...
# Variable DESERTA creada ✔️
# Creando variable ANIOS_MATRICULADO...
# Variable ANIOS_MATRICULADO creada ✔️
# Guardando dataset final en ../../data/processed/conare_modelo.csv...
# Dataset final listo ✔️🎉
