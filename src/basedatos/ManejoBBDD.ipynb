# %% [markdown]
# # Manejo de Bases de Datos

# %% [markdown]
# ### Ingreso de información en la base

# %%
import pyodbc

# %%
from src.basedatos.GestorBaseDatos import GestorBaseDatos

# %%
gestor = GestorBaseDatos(
    server="EVELYN\\SQLEXPRESS",
    database="DatosCrudosImportantes"
)
# Out:
# Conexión creada con la base 'DatosCrudosImportantes' en el servidor 'EVELYN\SQLEXPRESS'

# %%
gestor.cargar_csv(
    ruta_archivo="data/processed/datos_inec_convertidos1.csv",
    nombre_tabla="IndicadoresSocioeconomicos"
)

# %%
gestor.cargar_excel(
    ruta_archivo="data/raw/BD Matrícula Sector Estatal 2021_2024.xlsx",
    hoja="Archivo 2021-2024",
    nombre_tabla="DatosUniversidades"
)
