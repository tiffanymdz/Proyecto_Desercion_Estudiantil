# %%
from src.modelos.ModeloML import ModeloML

# %%
modelo = ModeloML("../data/processed/conare_modelo.csv")

# %%
modelo.cargar_datos()
# Out:
# ✔ Datos cargados correctamente.
# C:\Users\eveca\OneDrive\Escritorio\Proyecto_Desercion_Estudiantil\src\modelos\ModeloML.py:45: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(self.ruta_datos)
#          AÑO     TIPO_MATRICULA                UNIVERSIDAD  \
# 0       2021  No primer ingreso  Universidad de Costa Rica
# 1       2021  No primer ingreso  Universidad de Costa Rica
# 2       2021  No primer ingreso  Universidad de Costa Rica
# 3       2021  No primer ingreso  Universidad de Costa Rica
# 4       2021  No primer ingreso  Universidad de Costa Rica
# ...      ...                ...                        ...
# 488107  2024     Primer ingreso  Tecnológico de Costa Rica
# 488108  2024     Primer ingreso  Tecnológico de Costa Rica
# 488109  2024     Primer ingreso  Tecnológico de Costa Rica
# 488110  2024  No primer ingreso  Tecnológico de Costa Rica
# 488111  2024  No primer ingreso  Tecnológico de Costa Rica
#
#                                                   CARRERA    SEXO EDAD  \
# 0                                   Dirección de Empresas   Mujer   24
# 1                                   Dirección de Empresas   Mujer   23
# 2                                      Contaduría Pública   Mujer   22
# 3             Enseñanza del Inglés como Lengua Extranjera   Mujer   28
# 4                                               Geografía   Mujer   19
# ...                                                   ...     ...  ...
# 488107  Administración de Empresas énfasis Recursos Hu...   Mujer   44
# 488108  Administración de Empresas énfasis Recursos Hu...   Mujer   36
# 488109                              Dirección de Empresas   Mujer   34
# 488110  Enseñanza de la Matemática con Entornos Tecnol...  Hombre   57
# 488111                         Administración de Empresas  Hombre   45
#
#        PROVINCIA_ESTUDIANTE    CANTON_ESTUDIANTE ZONA_URBANO_RURAL_ESTUDIANTE  \
# 0                PUNTARENAS           PUNTARENAS                        RURAL
# 1                PUNTARENAS           PUNTARENAS                        RURAL
# 2                PUNTARENAS           PUNTARENAS                        RURAL
# 3                PUNTARENAS           PUNTARENAS                        RURAL
# 4                PUNTARENAS           PUNTARENAS                        RURAL
# ...                     ...                  ...                          ...
# 488107           GUANACASTE              TILARAN                       URBANO
# 488108                LIMON            SIQUIRRES                       URBANO
# 488109             ALAJUELA             ALAJUELA                       URBANO
# 488110              CARTAGO            TURRIALBA                       URBANO
# 488111             SAN JOSE  VAZQUEZ DE CORONADO                       URBANO
#
#        GAM_ESTUDIANTE    AREA_CONOCIMIENTO  \
# 0              No GAM  Ciencias Económicas
# 1              No GAM  Ciencias Económicas
# 2              No GAM  Ciencias Económicas
# 3              No GAM            Educación
# 4              No GAM   Recursos Naturales
# ...               ...                  ...
# 488107         No GAM  Ciencias Económicas
# 488108         No GAM  Ciencias Económicas
# 488109            GAM  Ciencias Económicas
# 488110         No GAM            Educación
# 488111            GAM  Ciencias Económicas
#
#                                             ID_ESTUDIANTE  DESERTA  \
# 0       Universidad de Costa Rica_Dirección de Empresa...        1
# 1       Universidad de Costa Rica_Dirección de Empresa...        1
# 2       Universidad de Costa Rica_Contaduría Pública_M...        1
# 3       Universidad de Costa Rica_Enseñanza del Inglés...        1
# 4       Universidad de Costa Rica_Geografía_Mujer_19_P...        0
# ...                                                   ...      ...
# 488107  Tecnológico de Costa Rica_Administración de Em...        0
# 488108  Tecnológico de Costa Rica_Administración de Em...        0
# 488109  Tecnológico de Costa Rica_Dirección de Empresa...        1
# 488110  Tecnológico de Costa Rica_Enseñanza de la Mate...        0
# 488111  Tecnológico de Costa Rica_Administración de Em...        1
#
#         ANIOS_MATRICULADO
# 0                       4
# 1                       4
# 2                       3
# 3                       1
# 4                       1
# ...                   ...
# 488107                  1
# 488108                  1
# 488109                  2
# 488110                  1
# 488111                  2
#
# [488112 rows x 14 columns]

# %%
# CLASIFICACIÓN
modelo.preparar_clasificacion()
modelo.entrenar_clasificacion()
modelo.evaluar_clasificacion()
# Out:
# Preparando datos para CLASIFICACIÓN...
# ✔ Clasificación lista.
# Entrenando modelo de CLASIFICACIÓN...
# ✔ Modelo de clasificación entrenado.
#
# 📊 Accuracy: 0.7156
#
# 📄 Reporte:
#               precision    recall  f1-score   support
#
#            0       0.55      0.82      0.66     32582
#            1       0.88      0.67      0.76     65041
#
#     accuracy                           0.72     97623
#    macro avg       0.71      0.74      0.71     97623
# weighted avg       0.77      0.72      0.72     97623
# (0.7156407813732419,
#  array([[26594,  5988],
#         [21772, 43269]]))

# %%
# REGRESIÓN
modelo.preparar_regresion()
# Out:
# Preparando datos para REGRESIÓN...
# ✔ Regresión lista.
# (         AÑO  TIPO_MATRICULA_No primer ingreso  TIPO_MATRICULA_Primer Ingreso  \
#  78893   2021                              True                          False
#  279697  2023                              True                          False
#  41663   2021                              True                          False
#  227250  2022                              True                          False
#  265158  2023                              True                          False
#  ...      ...                               ...                            ...
#  259178  2023                              True                          False
#  365838  2023                             False                          False
#  131932  2022                              True                          False
#  146867  2022                              True                          False
#  121958  2021                              True                          False
#
#          TIPO_MATRICULA_Primer ingreso  \
#  78893                           False
#  279697                          False
#  41663                           False
#  227250                          False
#  265158                          False
#  ...                               ...
#  259178                          False
#  365838                           True
#  131932                          False
#  146867                          False
#  121958                          False
#
#          UNIVERSIDAD_Universidad Estatal a Distancia  \
#  78893                                          True
#  279697                                        False
#  41663                                         False
#  227250                                         True
#  265158                                        False
#  ...                                             ...
#  259178                                        False
#  365838                                        False
#  131932                                        False
#  146867                                        False
#  121958                                        False
#
#          UNIVERSIDAD_Universidad Nacional  \
#  78893                              False
#  279697                             False
#  41663                              False
#  227250                             False
#  265158                             False
#  ...                                  ...
#  259178                             False
#  365838                             False
#  131932                             False
#  146867                             False
#  121958                             False
#
#          UNIVERSIDAD_Universidad Técnica Nacional  \
#  78893                                      False
#  279697                                     False
#  41663                                      False
#  227250                                     False
#  265158                                     False
#  ...                                          ...
#  259178                                     False
#  365838                                      True
#  131932                                     False
#  146867                                     False
#  121958                                      True
#
#          UNIVERSIDAD_Universidad de Costa Rica  CARRERA_Administración  \
#  78893                                   False                   False
#  279697                                   True                   False
#  41663                                    True                   False
#  227250                                  False                   False
#  265158                                   True                   False
#  ...                                       ...                     ...
#  259178                                   True                   False
#  365838                                  False                   False
#  131932                                   True                   False
#  146867                                   True                   False
#  121958                                  False                   False
#
#          CARRERA_Administración Aduanera  ...  GAM_ESTUDIANTE_Sin información  \
#  78893                             False  ...                           False
#  279697                            False  ...                           False
#  41663                             False  ...                           False
#  227250                            False  ...                           False
#  265158                            False  ...                           False
#  ...                                 ...  ...                             ...
#  259178                            False  ...                           False
#  365838                            False  ...                           False
#  131932                            False  ...                           False
#  146867                            False  ...                           False
#  121958                            False  ...                           False
#
#          AREA_CONOCIMIENTO_Ciencias Básicas  \
#  78893                                False
#  279697                               False
#  41663                                False
#  227250                               False
#  265158                               False
#  ...                                    ...
#  259178                               False
#  365838                               False
#  131932                               False
#  146867                               False
#  121958                               False
#
#          AREA_CONOCIMIENTO_Ciencias Económicas  \
#  78893                                    True
#  279697                                   True
#  41663                                   False
#  227250                                  False
#  265158                                  False
#  ...                                       ...
#  259178                                  False
#  365838                                  False
#  131932                                  False
#  146867                                  False
#  121958                                   True
#
#          AREA_CONOCIMIENTO_Ciencias Sociales  \
#  78893                                 False
#  279697                                False
#  41663                                  True
#  227250                                False
#  265158                                False
#  ...                                     ...
#  259178                                False
#  365838                                False
#  131932                                False
#  146867                                False
#  121958                                False
#
#          AREA_CONOCIMIENTO_Ciencias de la Salud  AREA_CONOCIMIENTO_Computación  \
#  78893                                    False                          False
#  279697                                   False                          False
#  41663                                    False                          False
#  227250                                   False                          False
#  265158                                   False                          False
#  ...                                        ...                            ...
#  259178                                   False                          False
#  365838                                   False                          False
#  131932                                   False                          False
#  146867                                   False                          False
#  121958                                   False                          False
#
#          AREA_CONOCIMIENTO_Derecho  AREA_CONOCIMIENTO_Educación  \
#  78893                       False                        False
#  279697                      False                        False
#  41663                       False                        False
#  227250                      False                        False
#  265158                      False                        False
#  ...                           ...                          ...
#  259178                      False                        False
#  365838                      False                        False
#  131932                      False                         True
#  146867                      False                        False
#  121958                      False                        False
#
#          AREA_CONOCIMIENTO_Ingeniería  AREA_CONOCIMIENTO_Recursos Naturales
#  78893                          False                                 False
#  279697                         False                                 False
#  41663                          False                                 False
#  227250                         False                                 False
#  265158                         False                                  True
#  ...                              ...                                   ...
#  259178                          True                                 False
#  365838                          True                                 False
#  131932                         False                                 False
#  146867                          True                                 False
#  121958                         False                                 False
#
#  [390489 rows x 957 columns],
#           AÑO  TIPO_MATRICULA_No primer ingreso  TIPO_MATRICULA_Primer Ingreso  \
#  163225  2022                              True                          False
#  114822  2021                              True                          False
#  256869  2023                              True                          False
#  70561   2021                              True                          False
#  206110  2022                              True                          False
#  ...      ...                               ...                            ...
#  211850  2022                              True                          False
#  410682  2024                             False                           True
#  125465  2022                              True                          False
#  47710   2021                              True                          False
#  155737  2022                              True                          False
#
#          TIPO_MATRICULA_Primer ingreso  \
#  163225                          False
#  114822                          False
#  256869                          False
#  70561                           False
#  206110                          False
#  ...                               ...
#  211850                          False
#  410682                          False
#  125465                          False
#  47710                           False
#  155737                          False
#
#          UNIVERSIDAD_Universidad Estatal a Distancia  \
#  163225                                        False
#  114822                                        False
#  256869                                        False
#  70561                                         False
#  206110                                         True
#  ...                                             ...
#  211850                                         True
#  410682                                        False
#  125465                                        False
#  47710                                         False
#  155737                                        False
#
#          UNIVERSIDAD_Universidad Nacional  \
#  163225                             False
#  114822                             False
#  256869                             False
#  70561                               True
#  206110                             False
#  ...                                  ...
#  211850                             False
#  410682                             False
#  125465                             False
#  47710                              False
#  155737                             False
#
#          UNIVERSIDAD_Universidad Técnica Nacional  \
#  163225                                     False
#  114822                                      True
#  256869                                     False
#  70561                                      False
#  206110                                     False
#  ...                                          ...
#  211850                                     False
#  410682                                     False
#  125465                                     False
#  47710                                      False
#  155737                                     False
#
#          UNIVERSIDAD_Universidad de Costa Rica  CARRERA_Administración  \
#  163225                                   True                   False
#  114822                                  False                   False
#  256869                                   True                   False
#  70561                                   False                   False
#  206110                                  False                   False
#  ...                                       ...                     ...
#  211850                                  False                   False
#  410682                                   True                   False
#  125465                                   True                   False
#  47710                                   False                   False
#  155737                                   True                   False
#
#          CARRERA_Administración Aduanera  ...  GAM_ESTUDIANTE_Sin información  \
#  163225                            False  ...                           False
#  114822                            False  ...                           False
#  256869                            False  ...                           False
#  70561                             False  ...                           False
#  206110                            False  ...                           False
#  ...                                 ...  ...                             ...
#  211850                            False  ...                           False
#  410682                            False  ...                           False
#  125465                            False  ...                           False
#  47710                             False  ...                           False
#  155737                            False  ...                           False
#
#          AREA_CONOCIMIENTO_Ciencias Básicas  \
#  163225                               False
#  114822                               False
#  256869                               False
#  70561                                False
#  206110                               False
#  ...                                    ...
#  211850                               False
#  410682                               False
#  125465                               False
#  47710                                False
#  155737                               False
#
#          AREA_CONOCIMIENTO_Ciencias Económicas  \
#  163225                                   True
#  114822                                  False
#  256869                                  False
#  70561                                   False
#  206110                                  False
#  ...                                       ...
#  211850                                  False
#  410682                                  False
#  125465                                  False
#  47710                                   False
#  155737                                  False
#
#          AREA_CONOCIMIENTO_Ciencias Sociales  \
#  163225                                False
#  114822                                False
#  256869                                False
#  70561                                 False
#  206110                                False
#  ...                                     ...
#  211850                                False
#  410682                                False
#  125465                                False
#  47710                                 False
#  155737                                False
#
#          AREA_CONOCIMIENTO_Ciencias de la Salud  AREA_CONOCIMIENTO_Computación  \
#  163225                                   False                          False
#  114822                                   False                          False
#  256869                                   False                          False
#  70561                                    False                          False
#  206110                                   False                           True
#  ...                                        ...                            ...
#  211850                                    True                          False
#  410682                                   False                          False
#  125465                                   False                          False
#  47710                                    False                          False
#  155737                                   False                          False
#
#          AREA_CONOCIMIENTO_Derecho  AREA_CONOCIMIENTO_Educación  \
#  163225                      False                        False
#  114822                      False                        False
#  256869                      False                        False
#  70561                       False                         True
#  206110                      False                        False
#  ...                           ...                          ...
#  211850                      False                        False
#  410682                      False                        False
#  125465                      False                        False
#  47710                       False                        False
#  155737                      False                         True
#
#          AREA_CONOCIMIENTO_Ingeniería  AREA_CONOCIMIENTO_Recursos Naturales
#  163225                         False                                 False
#  114822                         False                                  True
#  256869                          True                                 False
#  70561                          False                                 False
#  206110                         False                                 False
#  ...                              ...                                   ...
#  211850                         False                                 False
#  410682                          True                                 False
#  125465                         False                                 False
#  47710                           True                                 False
#  155737                         False                                 False
#
#  [97623 rows x 957 columns],
#  78893     3
#  279697    2
#  41663     2
#  227250    3
#  265158    4
#           ..
#  259178    2
#  365838    3
#  131932    1
#  146867    4
#  121958    1
#  Name: ANIOS_MATRICULADO, Length: 390489, dtype: int64,
#  163225    4
#  114822    1
#  256869    2
#  70561     2
#  206110    2
#           ..
#  211850    4
#  410682    1
#  125465    4
#  47710     1
#  155737    1
#  Name: ANIOS_MATRICULADO, Length: 97623, dtype: int64)

# %%
modelo.entrenar_regresion()
# Out:
# Entrenando modelo de REGRESIÓN...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 modelo.entrenar_regresion()
#
# File ~\OneDrive\Escritorio\Proyecto_Desercion_Estudiantil\src\modelos\ModeloML.py:154, in ModeloML.entrenar_regresion(self)
#     143 print("Entrenando modelo de REGRESIÓN...")
#     145 self.modelo_regresion = RandomForestRegressor(
#     146     n_estimators=150,  # suficiente para gran precisión
#     147     max_depth=16,  # evita árboles gigantes que duran 40 minutos
#    (...)    151     random_state=42
#     152 )
# --> 154 self.modelo_regresion.fit(self.Xr_train, self.yr_train)
#     155 print("✔ Modelo de regresión entrenado.")
#     156 return self.modelo_regresion
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
modelo.evaluar_regresion()

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
